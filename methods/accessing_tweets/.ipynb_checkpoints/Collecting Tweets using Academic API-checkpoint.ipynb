# %% [markdown]
# # Collecting Tweets using Twitter Academic API

# %% [markdown]
# ## 1. Import Packages & Define Key Variables

# %%
# Import packages
import yaml
from searchtweets import ResultStream, gen_request_parameters, load_credentials, collect_results

# Define rootpath
rp = 'C:\\Users\\sgmmahon\\Documents\\GitHub\\iom_project\\'
mp = 'methods\\accessing_tweets\\'
dp = 'data\\tweet_data\\'

# %%
# Define YAML with key details for accessing Twitter API
config = dict(
    search_tweets_v2=dict(
        endpoint=f"https://api.twitter.com/2/tweets/search/all",
        consumer_key='n5q87cELjVKlO7Z8MXXjp0Chr',
        consumer_secret='Tg3bEINKtvvxXpD5HwyJ2bCtd99RQl8aeJXMEma1SsE6Q3zLXa',
        bearer_token='AAAAAAAAAAAAAAAAAAAAABLt8wAAAAAAbE8U4tJJtQffIvLTtuHWVzm0nqI%3DIinQPSHHGhYjXwG71L4AHkUnUmlP9X8npfKQ0S6Nk07nBSF8AY'
    )
)


# Save YAML file
with open(rp + mp + 'twitter_keys.yaml', 'w') as config_file:
    yaml.dump(config, config_file, default_flow_style=False)

# %%
# Define rules for academic search for streaming tweets
academic_search_args = load_credentials(filename=rp + mp + 'twitter_keys.yaml',
                                        yaml_key="search_tweets_v2",
                                        env_overwrite=False)

# %% [markdown]
# ## 2. Define Search Terms

# %%
# Create functions which concatenates vectors
def cnct (x): return(" OR ".join(x))
def cnctwb (x): return("(" + " OR ".join(x) + ")")

# %%
# UK Search Terms# UK Search Terms

# Migrant terms
uk_neutral_migrant_terms  = ["immigrant", "immigration", "migrant", "migration", "\"asylum seeker\"", "refugee", "\"undocumented worker\"", "\"guest worker\"", 
                             "\"EU worker\"", "\"non-UK workers\"", "\"foreign worker\"", "(human smuggling)", "(human trafficking)"]
uk_negative_migrant_terms = ["illegals", "foreigner", "\"illegal alien\"", "\"illegal worker\""]
 
# Racial terms
uk_negative_racial_terms  = ["islamophob", "sinophob", "\"china flu\"", "\"kung flu\"", "\"china virus\"", "\"chinese virus\"", "shangainese"]

# Twitter accounts
uk_pro_migrant_account_1  = ["@UNmigration", "@IOM_UN", "@IOMatUN", "@IOMatEU", "@IOM_UK", "@IOMResearch", "@IOM_GMDAC", "@hrw", "@Right_to_Remain",
                             "@CommonsHomeAffs", "@fcukba", "@Mark_George_QC", "@MigrantVoiceUK", "@MigrantChildren", "@MigrantHelp", "@thevoiceofdws"]
uk_pro_migrant_account_2  = ["@WORCrights", "@UbuntuGlasgow", "@MigrantsUnionUK", "@migrants_rights", "@MigrantsMRC", "@Consenant_UK", "@RomaSupport",
                             "@MigrantsLawProj", "@MigRightsScot", "@IRMOLondon", "@HighlySkilledUK", "@WeBelong19", "@Project17UK"]
uk_neutral_account        = ["@ukhomeoffice", "@pritipatel", "@UKHomeSecretary", "@EUHomeAffairs", "@MigrMatters", "@MigObs"]
uk_anti_migrant_account   = ["@Nigel_Farage", "@MigrationWatch"]

# Hashtags
uk_positive_hashtags      = ["#RefugeesWelcome", "#MigrantsWelcome", "#LeaveNoOneBehind", "#FreedomForImmigrants", "#illegalmigantsUK", "#LondonIsOpen",
                             "#EndHostileEnvironment", "#FamiliesBelongTogether"]
uk_neutral_hashtags       = ["#Pritiuseless", "#migrationEU", "#immigration", "#migration", "#immigrant", "#migrant", "#immigrate", "#migrate", "#refugees",
                             "#NigelFarage", "#ImmigrationReform"]
uk_negative_hashtags      = ["#illegals", "#foreigner", "#foreigners", "#illegalalien", "#illegalaliens", "#illegalworker", "#illegalworkers", "#KeepThemOut",
                             "#OurCountry", "#SendThemBack", "#migrantsnotwelcome", "#refugeesnotwelcome", "#illegals", "#ChinaVirus", "#chinaflu", "#kungflu",
                             "#chinesevirus", "#TheyHaveToGoBack", "#DeportThemAll"]
uk_event_hashtags         = ["#Moria", "#CampFire", "#closethecamps"]

# Define final search queries
uk_terms    = cnctwb([cnct(uk_neutral_migrant_terms), cnct(uk_negative_migrant_terms), cnct(uk_negative_racial_terms)])
uk_accounts = cnctwb([cnct(uk_pro_migrant_account_1), cnct(uk_pro_migrant_account_2), cnct(uk_neutral_account), cnct(uk_anti_migrant_account)])
uk_hashtags = cnctwb([cnct(uk_positive_hashtags), cnct(uk_neutral_hashtags), cnct(uk_negative_hashtags), cnct(uk_event_hashtags)])

# Append all search term into single list
uk_search_terms = uk_neutral_migrant_terms + uk_negative_migrant_terms + uk_negative_racial_terms + uk_pro_migrant_account_1 + \
                  uk_pro_migrant_account_2 + uk_neutral_account + uk_positive_hashtags + uk_neutral_hashtags + uk_negative_hashtags + uk_event_hashtags


# USA Search Terms

# Migrant terms
usa_neutral_migrant_terms  = ["immigrant", "immigration", "migrant", "migration", "\"asylum seeker\"", "refugee", "\"undocumented worker\"", "\"guest worker\"", 
                              "\"foreign worker\"", "(human smuggling)", "(human trafficking)"]
usa_negative_migrant_terms = ["illegals", "foreigner", "\"illegal alien\"", "\"illegal worker\""]
 
# Racial terms
usa_negative_racial_terms  = ["islamophob", "sinophob", "\"china flu\"", "\"kung flu\"", "\"china virus\"", "\"chinese virus\"", "shangainese"]

# Twitter accounts
usa_pro_migrant_account_1  = ["@UNmigration", "@IOM_UN", "@IOMatUN", "@IOMatEU", "@IOM_UK", "@IOMResearch", "@IOM_GMDAC", "@hrw", "@NIJC", "@CIYJA", 
                              "@ImmAdvocates", "@NWIRP", "@RAICESTEXAS", "@ImmJusticeNOW", "@icirr", "@IAmAnImmigrant", "@Am4ImmJustice", "@NILCJusticeFund"]
usa_pro_migrant_account_2  = ["@CIRCimmigrant", "@FLImmigrant", "@ImmFamTogether", "@ImmJustice", "@NICE4Workers", "@CA4ImmiJustice", "@immigrantarc", "@Join_SIM",
                              "@SDIRC", "@RMIAN_org", "@NJAIJ", "@NVImmigrants", "@VA_Immigrants"]
usa_neutral_account        = ["@ICEgov", "@PhillyOIA", "@iandraffairs", "@LAC4Immigrants", "@CoreCivic"]
usa_anti_migrant_account   = ["@EuropidWhites"]

# Hashtags
usa_positive_hashtags      = ["#RefugeesWelcome", "#MigrantsWelcome", "#LeaveNoOneBehind", "#FreedomForImmigrants", "#illegalmigantsUSA", "#KillTheImmigrationBill", 
                              "#ImmigrantsMakeAmericaGreat", "#NoWall", "#NoWallEver", "#NoBan", "#FamiliesBelongTogether", "#stopICEcold", "#EndRemainInMexico"]
usa_neutral_hashtags       = ["#ICE", "#immigration", "#migration", "#immigrant", "#migrant", "#immigrate", "#migrate", "#refugees", "#ImmigrationReform"]
usa_negative_hashtags      = ["#illegals", "#foreigner", "#foreigners", "#illegalalien", "#illegalaliens", "#illegalworker", "#illegalworkers", "#KeepThemOut",
                              "#OurCountry", "#SendThemBack", "#migrantsnotwelcome", "#refugeesnotwelcome", "#illegals", "#ChinaVirus", "#chinaflu", "#kungflu",
                              "#chinesevirus", "#TheyHaveToGoBack", "#DeportThemAll"]
usa_event_hashtags         = ["#Moria", "#closethecamps", "#divestfromdetention"]

# Define final search queries
usa_terms    = cnctwb([cnct(usa_neutral_migrant_terms), cnct(usa_negative_migrant_terms), cnct(usa_negative_racial_terms)])
usa_accounts = cnctwb([cnct(usa_pro_migrant_account_1), cnct(usa_pro_migrant_account_2), cnct(usa_neutral_account), cnct(usa_anti_migrant_account)])
usa_hashtags = cnctwb([cnct(usa_positive_hashtags), cnct(usa_neutral_hashtags), cnct(usa_negative_hashtags), cnct(usa_event_hashtags)])

# Append all search term into single list
usa_search_terms = usa_neutral_migrant_terms + usa_negative_migrant_terms + usa_negative_racial_terms + usa_pro_migrant_account_1 + \
                   usa_pro_migrant_account_2 + usa_neutral_account + usa_positive_hashtags + usa_neutral_hashtags + usa_negative_hashtags + usa_event_hashtags



# Country Search Terms
uk_add_terms     = ' lang:en place_country:GB'
usa_add_terms    = ' lang:en (place_country:US OR profile_country:US)'

# %% [markdown]
# ## 3. Search Tweets

# %%
help(gen_request_parameters)
# Out:
# Help on function gen_request_parameters in module searchtweets.api_utils:
#
# gen_request_parameters(query, granularity, results_per_call=None, start_time=None, end_time=None, since_id=None, until_id=None, tweet_fields=None, user_fields=None, media_fields=None, place_fields=None, poll_fields=None, expansions=None, stringify=True)
#     Generates the dict or json payload for a search query.
#
#     Args:
#         query (str): The string version of a search query,
#             e.g., "snow has:media -is:retweet". Accepts multi-line strings
#             for ease of entry.
#         results_per_call (int): number of tweets or counts returned per API
#         call. This maps to the `max_results`` search API parameter.
#             Defaults to 100 (maximum supported in Labs).
#         start_time (str or None): Date format as specified by
#             `convert_utc_time` for the starting time of your search.
#         end_time (str or None): date format as specified by `convert_utc_time`
#             for the end time of your search.
#         tweet_fields (string): comma-delimted list of Tweet JSON attributes wanted in endpoint responses. Default is "id,created_at,text").
#         Also user_fields, media_fields, place_fields, poll_fields
#         expansions (string): comma-delimited list of object expansions.
#         stringify (bool): specifies the return type, `dict`
#             or json-formatted `str`.
#
#     Example:
#
#         >>> from searchtweets.utils import gen_request_parameters
#         >>> gen_request_parameters("snow has:media -is:retweet",
#             ...              from_date="2020-02-18",
#             ...              to_date="2020-02-21")
#         '{"query":"snow has:media -is:retweet","max_results":100,"start_time":"202002180000","end_time":"202002210000"}'

# %%
query = gen_request_parameters(uk_terms + uk_add_terms, results_per_call=100, granularity="hour",start_time = "2020-02-01T00:00")
query
# Out:
# '{"query":"(immigrant OR immigration OR migrant OR migration OR \\"asylum seeker\\" OR refugee OR \\"undocumented worker\\" OR \\"guest worker\\" OR \\"EU worker\\" OR \\"non-UK workers\\" OR \\"foreign worker\\" OR (human smuggling) OR (human trafficking) OR illegals OR foreigner OR \\"illegal alien\\" OR \\"illegal worker\\" OR islamophob OR sinophob OR \\"china flu\\" OR \\"kung flu\\" OR \\"china virus\\" OR \\"chinese virus\\" OR shangainese) lang:en place_country:GB","start_time":"2020-02-01T00:00:00Z","granularity":"hour"}'

# %%
# Query inputs
search_terms = uk_terms
add_terms = uk_add_terms
max_results = 100
granularity = "hour"
start_time  = '\"2020-02-01T00:00:00Z\"'
end_time    = '\"2020-02-08T00:00:00Z\"'

# Build queries
tweet_full_query  = '{"query":' + '"' + search_terms.replace('"', '\\"') + add_terms.replace('"', '\\"') + '"' + ',"max_results":' + str(max_results) + \
                    ',"start_time":' + str(start_time) + ',"end_time":' + str(end_time) + '}'
tweet_count_query = '{"query":' + '"' + search_terms.replace('"', '\\"') + add_terms.replace('"', '\\"') + '"' + ',"granulalarity":' + granularity + '}'
tweet_full_query
# Out:
# '{"query":"(immigrant OR immigration OR migrant OR migration OR \\"asylum seeker\\" OR refugee OR \\"undocumented worker\\" OR \\"guest worker\\" OR \\"EU worker\\" OR \\"non-UK workers\\" OR \\"foreign worker\\" OR (human smuggling) OR (human trafficking) OR illegals OR foreigner OR \\"illegal alien\\" OR \\"illegal worker\\" OR islamophob OR sinophob OR \\"china flu\\" OR \\"kung flu\\" OR \\"china virus\\" OR \\"chinese virus\\" OR shangainese) lang:en place_country:GB","max_results":100,"start_time":"2020-02-01T00:00:00Z","end_time":"2020-02-08T00:00:00Z"}'

# %%
tweets = collect_results(tweet_full_query,
                         max_tweets=100,
                         result_stream_args=academic_search_args)

# %%
help(collect_results)
# Out:
# Help on function collect_results in module searchtweets.result_stream:
#
# collect_results(query, max_tweets=1000, result_stream_args=None)
#     Utility function to quickly get a list of tweets from a ``ResultStream``
#     without keeping the object around. Requires your args to be configured
#     prior to using.
#     Args:
#         query (str): valid powertrack rule for your account, preferably
#         generated by the `gen_request_parameters` function.
#         max_tweets (int): maximum number of tweets or counts to return from
#         the API / underlying ``ResultStream`` object.
#         result_stream_args (dict): configuration dict that has connection
#         information for a ``ResultStream`` object.
#     Returns:
#         list of results
#     Example:
#         >>> from searchtweets import collect_results
#         >>> tweets = collect_results(query,
#                                      max_tweets=500,
#                                      result_stream_args=search_args)

# %%
rs = ResultStream(request_parameters=tweet_full_query,
                  max_results=500,
                  max_pages=1,
                  **academic_search_args)

# %%
tweets = list(rs.stream())

# %%
tweets[1]
# Out:
# {'data': [{'id': '1225511257635246080',
#    'text': '@DixonsAcademies Proud to work with your team @DixonsTA to provide a mentoring service to refugee young people. https://t.co/TY0TfCFYzI'},
#   {'id': '1225510503700746240',
#    'text': '@MigrationWatch @thedoctorxxx @talkRADIO @JuliaHB1 @BorisJohnson  doing nothing about the illegals coming from a safe country is NOT helping your cause.'},
#   {'id': '1225506268896464896',
#    'text': "Always impressed with @Care4Calais, call them at 1930 with a 'can you do @SkyNews' and straight away it's a yes.  #teamwork #migration #RefugeesWelcome"},
#   {'id': '1225505435265970176',
#    'text': '@BathNESUKIP @BorisJohnson  Get on with your promises. Or are all these illegals top grade migrants?'},
#   {'id': '1225499288802865153',
#    'text': 'My advice if you are worried go with a friend when you report and have immigration lawyers number, or instruct lawyer first so they can immediately deal with HO without saying lawyer has no authority. Be prepared, take names and notes https://t.co/yb5Ey59tWo'},
#   {'id': '1225498633287675905',
#    'text': '@DixonsAcademies rated 2nd best trust in @educationgovuk National league tables! Great teachers @DixonsTA that offer good support to new refugee students #TeamBradford https://t.co/PxZLtZsvW7'},
#   {'id': '1225497583566626821',
#    'text': 'If this has a decent migration tool then I think a lot of people will be ready to leave Google properly https://t.co/sy6LWdDfg0'},
#   {'id': '1225495909418573830',
#    'text': '@karenwales66 Our local news here in Kent just stated 96 illegals crossed the channel today in probably 8 boats'},
#   {'id': '1225492324744073216',
#    'text': 'The forces of populism are pretty stable around the world - and have different flavours on the left and right in the US, per @CliffAYoung.\n\nOn the right, this is about nativism and anti-immigrant sentiment. On the left, the focus is economic inequality. #CultureClash https://t.co/w6SarWvz9E'},
#   {'id': '1225489626573438976',
#    'text': "@twonks64 @DeborahMeaden Not it isn't. They voted for Johnson because he lied and said he would get brexit done. It ain't done. They pretend all the businesses leaving the UK are going because of 'diesel'. They pretend brexit will mean less immigration. They are deluded and love it."},
#   {'id': '1225486309189410820',
#    'text': '@Morris__Bright Read his autobiography some years back, Russian immigrant family, hard life but achieved the American dream.  Take note Trump &amp; fellow racists.'},
#   {'id': '1225482889397141505',
#    'text': "As though my mum jus said shes got 'Kung Flu' 🤯😂😩 #coronavirus"},
#   {'id': '1225482786607435776',
#    'text': '@alansideshow @MadeleinaKay @olivieytruliey @ReJoinTheEU2 @twhite7101 @swissjldd Alan, the truth is that everything you’ve been told about fishing, refugees, immigration, easiest deal in the world, we hold all the cards, 350m, unelected bureaucrats and so on.... well, they were all lies. I’m sorry. Really. They screwed you big time.'},
#   {'id': '1225482008748593159',
#    'text': 'As @kenanmalik points out, John Casey changed his mind. Roger Scruton, who edited the Salisbury Review, never did,  and was happy to endorse Powell\'s views (both on immigration "and* on race/discrimination) 25 years later. https://t.co/jlx2t60ERn'},
#   {'id': '1225480024515645444',
#    'text': 'Thanks to our amazing volunteer lawyers, @HereForGoodLaw was able to channel the bleakness of Brexit Day into something positive and practical.\n\nWith @MayorofLondon @SadiqKhan we provided ~£30k of free immigration advice at City Hall, proving loud and clear that #LondonIsOpen 🇪🇺 https://t.co/xPjY5U3p3r'},
#   {'id': '1225475692369936385',
#    'text': 'Had an absolutely flawless lesson and then me and my instructor were too engrossed in watching immigration police arguing with some guy running a takeaway and then...'},
#   {'id': '1225471028283035653',
#    'text': '@Alison_Douglaz Have a look at Museum of London Archaology project working with objects taken from the Calais detention centres https://t.co/o7rqdlvNQs'},
#   {'id': '1225463003514097665',
#    'text': 'If French patrol boats were on hand why were these ILLEGAL IMMIGRANTS not taken back to France. I’m totally sick of this fast tracking illegals into #UK where almost impossible to get rid thereafter 🤮🤮🤬🤬 https://t.co/Ia8z23219I'},
#   {'id': '1225457691772039171',
#    'text': 'Guy immigrates into England from Scotland, has a pop at his old city because it is now “too multicultural” with that dreaded open immigration policy* of the EU. \n\n*yes, I know it isn’t really. https://t.co/3RxZq0nRav'},
#   {'id': '1225455700681396228',
#    'text': 'Shocking that leaving the EU is not stopping “illegal” immigration as I was told by a leaver that was her reason to vote for Brexit. https://t.co/fx26tLrnml'},
#   {'id': '1225453635527749632',
#    'text': '@NISHAHMED_ Exact same thing happened to me with this Kurdish guy, said he was an immigrant from Syria when that was a big issue and said he needed to get to his family by coach, used Islam as well. End of the day your intention is what matters £65 to him but bre reward to you'},
#   {'id': '1225441235470602240',
#    'text': "@Orwellian_EU @jedigardener @wrkclasshistory @sotiridi Or South Africans. Or possibly they meant it's a migrant into Africa. Or maybe its bullshit.."},
#   {'id': '1225440725799755781',
#    'text': '@sotiridi African migrant with white skin. Which part of Africa? Is it the part just underneath France?'},
#   {'id': '1225439305994297345',
#    'text': "There's only one group of people who can say they're real Americans and that's the tribes of the Indian nation, everyone else is an immigrant https://t.co/VmuAAaSwFM"},
#   {'id': '1225437838189252608',
#    'text': '@mazarashsha Aisha was 10 years younger than her elder sister Asma, whose age at the time of the hijrah, or migration to Madina, was about 28. It can be concluded that Hazrat Aisha was about 18 years old at migration. On her moving to the Prophet’s house, she was a young woman at 21'},
#   {'id': '1225435935673921537',
#    'text': 'Appalling - Boris Johnson says deportation of dozens of Caribbean nationals must go ahead https://t.co/wr6UHU4L7z'},
#   {'id': '1225433341664645120',
#    'text': 'Boris Johnson\xa0has vowed that the\xa0deportation of dozens of Caribbean nationals\xa0will go ahead amid evidence a claim that they are all “serious criminals” is untrue https://t.co/TdIsSJ9UUi'},
#   {'id': '1225432110669930496',
#    'text': 'GCSE English results raise difficult questions about whether we’re doing enough for British-born children. But they also make me very proud of our hard-working immigrant families. Lady B, who learnt English aged six, now beats me a Scrabble. Urgh!\n\nhttps://t.co/o6IYRnNnsU'},
#   {'id': '1225431312510726144',
#    'text': '‘The real problem is anti-immigration politics rather than immigration itself’ The inimitable @MayaGoodfellow and @minnierahman in conversation last night about #HostileEnvironment (@VersoBooks) thank you everyone for coming 🙏 https://t.co/DOB5DDCYTo'},
#   {'id': '1225430007494914048',
#    'text': 'His just called Coronavirus the “Kung Flu”. That’s me signing off for the day https://t.co/6wheNyWKAA'},
#   {'id': '1225422823067398145',
#    'text': "@CDennett @finnoconnell @ZoomSparky @notsocontrover1 @LeaveEUOfficial Let's get this right. It's you that doesn't want immigration; you don't speak for decent people."},
#   {'id': '1225420937048346625',
#    'text': '@SamHeughan @zappyzip1 Why suddenly is immigration wrong is what I want to know. Not being a political person I would like it to be explained to me.'},
#   {'id': '1225418131973312513',
#    'text': 'Immigration van heading south on charing cross rd near leicester sq @AntiRaids https://t.co/5bULYdjLz5'},
#   {'id': '1225408353511387141',
#    'text': 'Boris Johnson says deportation of dozens of Caribbean nationals must go ahead https://t.co/sgG6M0eWVt'},
#   {'id': '1225407693193654272',
#    'text': "If you'd like to become a bike buddy to a refugee and you live in the West Midlands you have until midday tomorrow to apply https://t.co/cMPtDSEFyd"},
#   {'id': '1225405549593997312',
#    'text': '@DmitryOpines Would bet it follows the rationale of wanting to invoke thoughts of the desired immigration changes.'},
#   {'id': '1225402126299521025',
#    'text': '@mini_squish @Chupacaubrey @chrisluck Minus the easy immigration part for the US'},
#   {'id': '1225401664749830145',
#    'text': '@AmnestyIpswich @AngryWomenSuff @GoldCaro @ISCREUK @suffolk_refugee @ISCRE_Official Thank you. #SuffolkSolidarity \nSaturday’s event is a community response to racism. Hope to see lots of you there. To support @ISCRE_Official https://t.co/gR3eprwlzz'},
#   {'id': '1225399260683931653',
#    'text': 'Migrant Access Project Plus Celebration \n@TouchstoneMAPP @to https://t.co/oR2WTO97ut'},
#   {'id': '1225390422018723840',
#    'text': '@gilberthealien @SkyNews These are illegals and not using passports or border control'},
#   {'id': '1225390347733348355',
#    'text': 'That’s the difficulty. We won’t know. Just watching and waiting. 🤞🤞🤞@BorisJohnson stop immigration on low skilled workers. https://t.co/iIVsuvZDwa'},
#   {'id': '1225389974197067776',
#    'text': '"Bridging the gap between evidence and the actual use of it at country level requires listening to and adressing concrete country needs" - Dr. Santino Severoni, Special Advisor  on Migration and Health, WHO Regional Office for Europe\n\n@WHO_Europe #WHO #health #LancetMigration https://t.co/f3Ujlo6wBU'},
#   {'id': '1225388310060785675',
#    'text': '@GeorgeWParker @sajidjavid That Home Office is a massive source of red tape for employees. Liberalise migration!'},
#   {'id': '1225385737962577921',
#    'text': 'Excellent work by one of our founder members @worldreach_WRS fantastic effort! So proud of you #borders #immigration #technology #digital #innovation https://t.co/ltktV2OXZE'},
#   {'id': '1225383865340039168',
#    'text': '# HouseofLords\n#endfgm\nI just asked @liz_sugg if she was confident the Home Office is providing appropriate refuge for activists against #FGM and girls at risk.\nShe said yes.\nBut serious cause for concern https://t.co/Htj849IGgw'},
#   {'id': '1225375130139922432',
#    'text': 'Epstein Island and the Deep State Roots of Human Trafficking https://t.co/OgRw8Ao4ER'},
#   {'id': '1225372844873392128',
#    'text': "@BorisJohnson I've had faith in you Boris, so far your doing a fantastic job considering the damage the extreme left have left you to repair, MBGA, take back our waters, fishing industry boom from then on , illegals deported, fit the crime punishment/criminals/terrorists,you know what we want."},
#   {'id': '1225370302546358272',
#    'text': 'LBC this morning. 5 Brexiters trying to suggest EU regs we can now get rid of. Bendy bananas ffs! And one complaining that the EU limited the amount of non EU immigration we could have. All 5 people: wrong. This stupendous ignorance got us Brexit.'},
#   {'id': '1225370017186877440',
#    'text': 'The gradual migration of Brie! @ The Cheese Society https://t.co/sbPWyXLMAT'},
#   {'id': '1225368561264287744',
#    'text': '🇬🇧 UK: School children hand in 75,000-strong petition to reunite refugee families | Amnesty International UK \n\nhttps://t.co/s0PtHn9fLc \nfrom @AmnestyUK'},
#   {'id': '1225368308544888832',
#    'text': '💥Migrant charges inquiry in @LG_NHS \n\n🤞set to examine that dark Experian experience\n\n✖️Hostile environment = hostile acts on vulnerable, migrants\n\n👇🏽@lowdownnhs @DrTonyOSullivan https://t.co/6DFq9ha4lz'},
#   {'id': '1225367367569547264',
#    'text': 'This legend probably wouldn’t have been allowed into the US under the Trump immigration regime .\nRIP Spartacus! @LouiseMensch @TheRickWilson @jwgop https://t.co/TAOkOcAfU5'},
#   {'id': '1225359775346708480',
#    'text': 'If you want advice see a good immigration lawyer or contact me (not that I’m saying I’m bad lol) but find someone you trust, it’s your life https://t.co/TYc1HyY3n0'},
#   {'id': '1225359249242492929',
#    'text': 'Join tonight’s emergency protest - 6pm Downing Street - No #racist deportations - end the #HostileEnvironment #WindrushScandal https://t.co/FSh15hidZa'},
#   {'id': '1225358955083390977',
#    'text': 'UK Immigration Amnesty, not now, now tomorrow, maybe never, what can be ... https://t.co/MSW7HrQi1d via @YouTube HO also has experience (legacy scheme regularising 500,000 files. So they can do it. The reason given was HO was broken. Is it any better today'},
#   {'id': '1225358420846534656',
#    'text': 'UK Immigration Amnesty, not now, now tomorrow, maybe never, what can be ... https://t.co/MSW7HrQi1d via @YouTube note: it took HO 2 days to radically change rules after a case Pankina. If they wanted to act it would be easy. So why not?'},
#   {'id': '1225351108668903424',
#    'text': 'don’t get me wrong, they will always come up with an excuse as to why that particular LGBT+ person, that particular migrant or that particular person of color doesn’t deserve their solidarity in that very instance. it could be that they are not queer enough for example.'},
#   {'id': '1225349755045367809',
#    'text': '@maryellenfield @Dan1763 @DmitryOpines And as I understand it Australian immigration system is designed to get people into the country!'},
#   {'id': '1225349693892374528',
#    'text': 'Not to be a broken record but: this violence from the UK home office also means many of us migrant workers on Tier 2 visas aren’t sure the law will protect us if we strike for 14 days as part of future @ucu actions so many won’t/can’t strike. Where is a public statement on this? https://t.co/dPxwcjfduw'},
#   {'id': '1225347546115137537',
#    'text': '@Only_in_Poland @BBCNorthampton They absolutely do not want non white immigration , hence being 97% white .'},
#   {'id': '1225347084154523654',
#    'text': '@pimlicat @troot49 Just keep reporting border control and immigration issues to it?'},
#   {'id': '1225346930475257856',
#    'text': 'Boris Johnson says deportation of dozens of Caribbean nationals must go ahead\nhttps://t.co/R73jJGRRhr'},
#   {'id': '1225345282923167744',
#    'text': 'Children need their parents. Help change the unfair rules keeping refugee families apart. Together we are going to help bring #familiestogether https://t.co/a7VUC0rlMM'},
#   {'id': '1225343228267941889',
#    'text': 'Issur Danielovitch Demsky born the poor son of an illiterate Russian-Jewish immigrant went on to become one of the most enduring Hollywood Icons of all time. He was also a great Philanthropist #KirkDouglasRIP #Diversity #Hollywood https://t.co/OcFaIyTV4s via @people'},
#   {'id': '1225342208204845056',
#    'text': "Intrigued by American Dirt? Want to read something more authentic? 'They honor immigrants': writers pick the greatest migration stories you should read\n\nhttps://t.co/VCuqpDXQbX"},
#   {'id': '1225335432063397889',
#    'text': "@ArguDaz @P_H_I_L_L @jpeculiar @Femi_Sorry @OwenJones84 Couple of points.\n\n1- You don't think demand impacts supply?\n2- We rely on Rest of the World migration far more than EU immigration when it comes to staffing the NHS. https://t.co/JaimwBjo36"},
#   {'id': '1225335408575291394',
#    'text': "An Arabic 'Sesame Street,' to help refugee children in the Middel East learn to cope with emotions of their intense traumas  https://t.co/w5fGOPDcbo"},
#   {'id': '1225332717237293058',
#    'text': "@lornasharp2 @wgsaraband 5\n\nAnd the X on the line stands in place of your name\nSo in the old story I'll bet that I came\nFrom Gael and Pict and Angle and Dane\nAnd a poor migrant girl who could not write her name\nIt's a common old story but it's mine just the same\nAll through the story the immigrants came"},
#   {'id': '1225332012040540160',
#    'text': 'UK Immigration Amnesty, not now, now tomorrow, maybe never, what can be ... https://t.co/MSW7HrQi1d via @YouTube @JCWI_UK @migrants_rights @JMigrants @migpolgroup @MigrantVoiceUK @ToeicV @Tier1Community @freemovementlaw @DetentionAction @DetentionForum @kareeshalawyer @Jay_LLM'},
#   {'id': '1225318652800643072',
#    'text': 'Will @ukhomeoffice act now to restore access to lawyers in migrant detention centres? Phone signal outage has cut off lifeline &amp; access to lawyers - even with imminent removal charter flight to Jamaica. I ask my MP @Royston_Smith to intervene #Windrush https://t.co/hugNuv0j67'},
#   {'id': '1225307187293061120',
#    'text': '#album4work Immigrant Flower - @SiobhanKenned16 🎶🎧 Still buzzing from a great night of music #thelivergirls @ Whiston railway station https://t.co/lc19LbXFnR'},
#   {'id': '1225306910410379264',
#    'text': 'Its Not the housing crisis idiot.\nITS THE IMMIGRATION CRISIS.\n\nTO MANY PEOPLE LIVING IN THE COUNTRY. SORRY WE ARE FULL.\n. https://t.co/fK3S3woxTB'},
#   {'id': '1225302256284831744',
#    'text': '@BorisJohnson who do you think you are? @realDonaldTrump?\n\nhttps://t.co/H0kQfNe1KT'},
#   {'id': '1225281930918232064',
#    'text': '@vijayasankarv I once hit immigration at @PHLAirport and was screamed at by a woman with an anti-SAP tirade “These people are coming here, and taking our jobs”.\n\nA very nice officer Hernández smiled at me and said “Sir, you must be very good at what you do”.'},
#   {'id': '1225216314907688960',
#    'text': "How low can Johnson sink, I bet it's even lower than this despicable action. How can anyone look at our country and think that Brexit and the Tory's is a win?\n\nBoris Johnson says deportation of dozens of Caribbean nationals must go ahead https://t.co/uU1XphOb93"},
#   {'id': '1225210103487434752',
#    'text': "@drrnja I meant to say immigration ISN'T the cause 😣\nI fucking hate Wednesday"},
#   {'id': '1225209448169398273',
#    'text': "@drrnja Don't bleat about housing shortages etc and still condone immigration at its present levels.\nImmigration is the cause, granted. \nWhere will they be housed when they arrive, which schools have vacancies. \nOoh! How about Tent City like Calais.🤔"},
#   {'id': '1225207201519820800',
#    'text': '@drrnja Totally agree. \nStop immigration immediately. \nBuild more houses or convert abandoned warehouses etc. There must be shitloads of empty govt buildings.\nMore schools and hospitals then we can allow more people in.'},
#   {'id': '1225203844772179968',
#    'text': 'Is now when we talk about how this violence from the UK home office also means many of us migrant workers on Tier 2 visas are not certain the law will protect us if we strike for 14 days as part of upcoming @ucu actions so therefore many will not/can not strike? https://t.co/ghrkHpPhqY'},
#   {'id': '1225203435357835265',
#    'text': '@imasurvivor66 @BorisJohnson @10DowningStreet Opposite my place one young migrant lives here 4bed house https://t.co/v7eCa0oQ2g'},
#   {'id': '1225196078980616192',
#    'text': '@MatthewJP82 @NadsDogs @CaptureTheSky82 @PolhomeEditor 10 years on and that note is still being used, there are many who switched from Labour to UKIP due to feeling betrayed by New Labour on immigration &amp; job protection. The Blair legacies are not good, that is the cost of his amazing victory and subsequent acts'},
#   {'id': '1225195172537028608',
#    'text': 'Yes, try being an immigrant... one never feels “at home” ... I’ve stopped judging myself for how restless I feel ;) https://t.co/79mAExHUpS'},
#   {'id': '1225187979968360448',
#    'text': 'Tonight it was inspiring to join Lisa Milroy, our former Artist Trustee, to celebrate her interactive art workshops between Kakuma Refugee Camp, Kenya, and London. Thanks to Lisa @VodafoneFdn and @Refugees students in Kakuma have visited @NationalGallery from their classrooms. https://t.co/wtZlvEFHB3'},
#   {'id': '1225187446943625217',
#    'text': 'Listened to group of Chinese students talking today about perceived experiences of racist discrimination in the UK, &amp; how it’d increased during #coronavirus . One account of recently visiting another city &amp; local teenagers covering their faces &amp; shouting “Chinese virus!” etc...'},
#   {'id': '1225177391536005120',
#    'text': "The Uk Mordern Slavery Act 2015 is the first national legislation to use the term 'morden slavery' and to explicitly target 'slavery' as opposed to 'human trafficking'.  \n#occupationaltherapystudent #Advancedprofessionaldiversity #CDP #pillars #thirdyearstudent"},
#   {'id': '1225175851974656002',
#    'text': 'MP launches new legal bid to allow asylum seekers to work after six months https://t.co/EY0QERPCes'},
#   {'id': '1225169929386807297',
#    'text': '@davidschneider Absolute nonsense £10 billion annual subscription to be allowed to run up a nearly £100 billion trade deficit and thats before you take into account loss of sovereignty, ability to control immigration etc etc etc.'},
#   {'id': '1225166749752090624',
#    'text': '@HHepplewhite No  . Needs one too stop mass immigration which will surely happen if Scotland joins the eu'},
#   {'id': '1225164661206790147',
#    'text': '@M1Patrick @JohnRowlett4 @Taylor26Susan @terrychristian I would only be "losing this argument" if I was advocating zero EU immigration as opposed to fair, managed, selective immigration. Happy for skilled EU citizens who can speak English, want to contribute and respect our values to live here.'},
#   {'id': '1225163846714904581',
#    'text': 'These #immigrant workers should be given #settledstatus in the #UK for stopping the fish 🎣 escaping to #France #trade #tradewar #fta #fush #brexit https://t.co/NkTQ0LCO1T'},
#   {'id': '1225160608179539974',
#    'text': 'Boris Johnson says deportation of dozens of Caribbean nationals must go ahead https://t.co/yRDayF2yIm'},
#   {'id': '1225158386771283969',
#    'text': 'I’m the son of an immigrant and I voted Brexit. This might hurt Ben’s brain. https://t.co/i8cxNA2WDw'},
#   {'id': '1225154707754188804',
#    'text': 'Oh look more immigration fear mongering .. worked last time https://t.co/Ke8NblwnAh'},
#   {'id': '1225152419245580288',
#    'text': '😱😱😱😱 How uneducated this fool really is 😱😱😱😱\n\n"It\'s all about immigration". But he\'ll still let European residents in even though he voted to leave!\n\nUnbelievable!!! https://t.co/jtRXdUIihr'},
#   {'id': '1225147699835686914',
#    'text': 'UK Immigration Amnesty, not now, now tomorrow, maybe never, what can be ... https://t.co/MSW7HrQi1d via @YouTube @JCWI_UK @ILPAimmigration @BarHumanRights @Tier1Community @HighlySkilledUK @AmnestyUK @refugeecouncil @migrantsatwork @DLPublicLaw @DuncanLewis @kareeshalawyer'},
#   {'id': '1225147272318668800',
#    'text': 'UK Immigration Amnesty, not now, now tomorrow, maybe never, what can be done? https://t.co/MSW7HrQi1d via @YouTube @DetentionForum @migpolgroup @ToeicV @migrants_rights @MigrantVoiceUK @migrantsorg @ImmigrationMdia @JMigrants @ILPAimmigration @DetentionAction @bhdsolicitors'},
#   {'id': '1225146717244403713',
#    'text': 'MP launches new legal bid to allow asylum seekers to work after six months https://t.co/gsnkshhVtn'},
#   {'id': '1225145866094288898',
#    'text': 'Tomorrow, @BorderCrossings’ bring their brand-new play, #TheGreatExperiment, to @The_Dugdale. Discover the roots of many Asian communities &amp; explore the buried history of 2 million Indian migrant labourers indentured to work across the globe https://t.co/GNnSKqMezx #Enfield https://t.co/7M9AxnFapZ'},
#   {'id': '1225144242215047168',
#    'text': '@MichaelAHorne @KieranALeigh @SkyNewsBreak He’s blocked Trumps main agenda on immigration reform and now he’s impeaching him despite 0 evidence to convict him in the biggest partisan hitjob in American history, his electoral past means nothing. As we’ve seen in this country, just because youre in a party it doesn’t ...'}],
#  'meta': {'newest_id': '1225511257635246080',
#   'oldest_id': '1225144242215047168',
#   'result_count': 99,
#   'next_token': 'b26v89c19zqg8o3fo71fwuzyylwjqqbqwjj7gc5e6798d'}}

# %%
help(ResultStream)
# Out:
# Help on class ResultStream in module searchtweets.result_stream:
#
# class ResultStream(builtins.object)
#  |  ResultStream(endpoint, request_parameters, bearer_token=None, extra_headers_dict=None, max_tweets=500, max_requests=None, output_format='r', **kwargs)
#  |
#  |  Class to represent an API query that handles two major functionality
#  |  pieces: wrapping metadata around a specific API call and automatic
#  |  pagination of results.
#  |  Args:
#  |      bearer_token (str): bearer token for v2.
#  |
#  |      endpoint (str): API endpoint.
#  |
#  |      request_parameters (json or dict): payload for the post request
#  |
#  |      max_tweets (int): max number results that will be returned from this
#  |      instance. Note that this can be slightly lower than the total returned
#  |      from the API call  - e.g., setting ``max_tweets = 10`` would return
#  |      ten results, but an API call will return at minimum 100 results by default.
#  |
#  |      max_requests (int): A hard cutoff for the number of API calls this
#  |      instance will make. Good for testing in v2 environment.
#  |
#  |      extra_headers_dict (dict): custom headers to add
#  |  Example:
#  |      >>> rs = ResultStream(**search_args, request_parameters=rule, max_pages=1)
#  |      >>> results = list(rs.stream())
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, endpoint, request_parameters, bearer_token=None, extra_headers_dict=None, max_tweets=500, max_requests=None, output_format='r', **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  check_counts(self)
#  |      Disables tweet parsing if the count API is used.
#  |
#  |  execute_request(self)
#  |      Sends the request to the API and parses the json response.
#  |      Makes some assumptions about the session length and sets the presence
#  |      of a "next" token.
#  |
#  |  formatted_output(self)
#  |
#  |  init_session(self)
#  |      Defines a session object for passing requests.
#  |
#  |  stream(self)
#  |      Main entry point for the data from the API. Will automatically paginate
#  |      through the results via the ``next`` token and return up to ``max_tweets``
#  |      tweets or up to ``max_requests`` API calls, whichever is lower.
#  |      Usage:
#  |          >>> result_stream = ResultStream(**kwargs)
#  |          >>> stream = result_stream.stream()
#  |          >>> results = list(stream)
#  |          >>> # or for faster usage...
#  |          >>> results = list(ResultStream(**kwargs).stream())
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  session_request_counter = 0
